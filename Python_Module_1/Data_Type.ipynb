# %%
x=-5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=int(10)

# %%
x=999999999999999999999999999999999999999999999

# %%
import sys 
x=10**1000
y=10**1000
print(x+y)
# Out:
# ...

# %%
x=10

# %%
print(sys.getsizeof(x))
# Out:
# 28

# %%
x=10**1000
print(sys.getsizeof(x))
# Out:
# 468

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004

# %%
x=10
y=0.1

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(round(0.1+0.2,5))
# Out:
# 0.3

# %%
x=3+2j

# %%
print(type(x))
# Out:
# <class 'complex'>

# %%
print(x.real)
# Out:
# 3.0

# %%
print(x.imag)
# Out:
# 2.0
