# %%
age=10

# %%
age
# Out:
# 10

# %%
age=20

# %%
age
# Out:
# 20

# %%
print(id(age))
# Out:
# 4387059648

# %%
x=500
y=500

# %%
print(id(x))
# Out:
# 4505394288

# %%
print(id(y))
# Out:
# 4505402480

# %%
a=500

# %%
b=a

# %%
print(id(a))
# Out:
# 4505394896

# %%
print(id(b))
# Out:
# 4505394896

# %%
age=20
age1=20

# %%
print(id(age))
# Out:
# 4387059648

# %%
print(id(age1))
# Out:
# 4387059648

# %%
a=256
b=256

# %%
print(id(a)==id(b))
# Out:
# True

# %%
x=257
y=257
print(id(x)==id(y))
# Out:
# False

# %%
1name="Raj"
# Out:
#   Cell In[19], line 1
#     1name="Raj"
#     ^
# SyntaxError: invalid decimal literal
